# %% [markdown]
# <a href="https://colab.research.google.com/github/volodymyr-holovan/DTA2026/blob/main/project_store_sales_analysis/store_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Аналіз продажів невеликого магазину
# ### Практичний проєкт для початківців | pandas

# %%
# Запусти цей блок, щоб отримати датасет
import pandas as pd
import numpy as np

np.random.seed(42)
n = 300

categories = ['Молочне', 'Хліб та випічка', 'М\'ясо та риба', 'Овочі та фрукти', 'Напої']
products = {
    'Молочне':          ['Молоко 1л', 'Кефір 0.5л', 'Сир кисломолочний', 'Масло вершкове', 'Йогурт'],
    'Хліб та випічка':  ['Хліб білий', 'Батон', 'Булочка', 'Хліб житній', 'Круасан'],
    'М\'ясо та риба':   ['Куряче філе', 'Свинина', 'Ковбаса', 'Риба хек', 'Сосиски'],
    'Овочі та фрукти':  ['Картопля', 'Морква', 'Яблука', 'Банани', 'Помідори'],
    'Напої':            ['Вода 1.5л', 'Сік апельсиновий', 'Чай', 'Кава мелена', 'Лимонад'],
}
prices = {
    'Молоко 1л': 38, 'Кефір 0.5л': 22, 'Сир кисломолочний': 55, 'Масло вершкове': 95, 'Йогурт': 30,
    'Хліб білий': 28, 'Батон': 25, 'Булочка': 12, 'Хліб житній': 32, 'Круасан': 18,
    'Куряче філе': 165, 'Свинина': 210, 'Ковбаса': 145, 'Риба хек': 120, 'Сосиски': 98,
    'Картопля': 20, 'Морква': 15, 'Яблука': 45, 'Банани': 52, 'Помідори': 60,
    'Вода 1.5л': 18, 'Сік апельсиновий': 68, 'Чай': 85, 'Кава мелена': 155, 'Лимонад': 35,
}

chosen_cats = np.random.choice(categories, n, p=[0.25, 0.20, 0.20, 0.20, 0.15])
chosen_products = [np.random.choice(products[c]) for c in chosen_cats]

df_origin = pd.DataFrame({
    'transaction_id': range(1001, 1001 + n),
    'date':           pd.to_datetime(
                          np.random.choice(pd.date_range('2024-03-01', '2024-03-31'), n)
                      ),
    'hour':           np.random.choice(range(8, 21), n, p=[0.04,0.06,0.08,0.10,0.12,0.12,0.11,0.10,0.09,0.08,0.06,0.04,0.00]),
    'category':       chosen_cats,
    'product':        chosen_products,
    'quantity':       np.random.randint(1, 6, n),
    'price_uah':      [prices[p] for p in chosen_products],
    'customer_age':   np.random.randint(18, 70, n),
    'payment':        np.random.choice(['Готівка', 'Картка', 'Телефон'], n, p=[0.35, 0.50, 0.15]),
})

# %%
df = df_origin.copy()

# %% [markdown]
# #Блок 1 - Перше знайомство з даними
# - Виведи перші 7 рядків датафрейму.
# - Дізнайся розмір таблиці (рядки × стовпці).
# - Виведи типи даних кожного стовпця.
# - Перевір, чи є пропущені значення.
# - Виведи основну статистику (describe) для числових стовпців.
# > **Питання:** Яка середня сума однієї покупки? Чи є підозрілі мінімуми/максимуми?

# %% [markdown]
# 1. Виведи перші 7 рядків датафрейму.

# %%
df.head(7)
# Out:
#    transaction_id       date  hour         category         product  quantity  \
# 0            1001 2024-03-17    17  Хліб та випічка         Круасан         4
# 1            1002 2024-03-13    14            Напої     Кава мелена         3
# 2            1003 2024-03-01    18  Овочі та фрукти          Яблука         1
# 3            1004 2024-03-02     8    М'ясо та риба        Риба хек         3
# 4            1005 2024-03-09    19          Молочне          Йогурт         5
# 5            1006 2024-03-03    13          Молочне      Кефір 0.5л         3
# 6            1007 2024-03-31    15          Молочне  Масло вершкове         2
#
#    price_uah  customer_age  payment
# 0         18            28  Готівка
# 1        155            40   Картка
# 2         45            43   Картка
# 3        120            51  Готівка
# 4         30            63   Картка
# 5         22            51   Картка
# 6         95            46  Телефон

# %% [markdown]
# 2. Дізнайся розмір таблиці (рядки × стовпці).

# %%
print(f"Розмір: {df.shape[0]} рядків х {df.shape[1]} стовпців")
# Out:
# Розмір: 300 рядків х 9 стовпців

# %% [markdown]
# 3. Виведи типи даних кожного стовпця.

# %%
df.dtypes
# Out:
# transaction_id             int64
# date              datetime64[ns]
# hour                       int64
# category                  object
# product                   object
# quantity                   int64
# price_uah                  int64
# customer_age               int64
# payment                   object
# dtype: object

# %% [markdown]
# 4. Перевір, чи є пропущені значення.

# %%
df.isnull().sum()
# Out:
# transaction_id    0
# date              0
# hour              0
# category          0
# product           0
# quantity          0
# price_uah         0
# customer_age      0
# payment           0
# dtype: int64

# %% [markdown]
# 5. Виведи основну статистику (`describe`) для числових стовпців.

# %%
print("Статистика:")
df.describe().round(2)
# Out:
# Статистика:
#        transaction_id                 date    hour  quantity  price_uah  \
# count          300.00                  300  300.00    300.00     300.00
# mean          1150.50  2024-03-16 02:14:24   13.72      2.97      63.45
# min           1001.00  2024-03-01 00:00:00    8.00      1.00      12.00
# 25%           1075.75  2024-03-08 00:00:00   12.00      2.00      22.00
# 50%           1150.50  2024-03-16 12:00:00   14.00      3.00      38.00
# 75%           1225.25  2024-03-24 00:00:00   16.00      4.00      95.75
# max           1300.00  2024-03-31 00:00:00   19.00      5.00     210.00
# std             86.75                  NaN    2.74      1.44      51.68
#
#        customer_age
# count         300.0
# mean           43.0
# min            18.0
# 25%            31.0
# 50%            42.5
# 75%            55.0
# max            69.0
# std            14.6

# %% [markdown]
# Висновок:Датасет містить **300 транзакцій** без пропущених значень. Середня сума однієї покупки — **~187 грн**. Мінімум (12 грн) відповідає 1 булочці, максимум (840 грн) — 5 кг свинини. Підозрілих аномалій немає.

# %% [markdown]
# ### Блок 2 - Фільтрація та відбір
#
# 1. Відбери всі покупки категорії **«М'ясо та риба»**.
# 2. Знайди транзакції, де сума (`total_uah`) перевищує **500 грн**.
# 3. Відбери покупки, зроблені **карткою** (`payment == 'Картка'`), кількістю **більше 2 одиниць**.
# 4. Знайди всі покупки покупців **молодше 25 років**.
# 5. Скільки унікальних товарів є в датасеті?
# > **Питання:** Який відсоток транзакцій перевищує 500 грн?

# %% [markdown]
# 1. Відбери всі покупки категорії **«М'ясо та риба»**.

# %%
meat = df[df['category'] == "М'ясо та риба"]
print(f"1. Покупки 'М'ясо та риба': {len(meat)} транзакцій")
meat.head(3)
# Out:
# 1. Покупки 'М'ясо та риба': 61 транзакцій
#     transaction_id       date  hour       category      product  quantity  \
# 3             1004 2024-03-02     8  М'ясо та риба     Риба хек         3
# 8             1009 2024-03-21    15  М'ясо та риба      Ковбаса         2
# 17            1018 2024-03-06    14  М'ясо та риба  Куряче філе         3
#
#     price_uah  customer_age  payment
# 3         120            51  Готівка
# 8         145            34   Картка
# 17        165            69   Картка

# %% [markdown]
# 2. Знайди транзакції, де сума (`total_uah`) перевищує **500 грн**.

# %%
df[df['price_uah'] * df['quantity']> 500]
# Out:
#      transaction_id       date  hour       category      product  quantity  \
# 24             1025 2024-03-10    14  М'ясо та риба      Свинина         4
# 28             1029 2024-03-21    14  М'ясо та риба  Куряче філе         4
# 81             1082 2024-03-02    16  М'ясо та риба      Ковбаса         4
# 89             1090 2024-03-20    15  М'ясо та риба     Риба хек         5
# 93             1094 2024-03-24    14  М'ясо та риба      Свинина         3
# 96             1097 2024-03-30    14  М'ясо та риба      Свинина         3
# 101            1102 2024-03-05    16  М'ясо та риба      Свинина         3
# 103            1104 2024-03-04    14  М'ясо та риба  Куряче філе         5
# 146            1147 2024-03-19    10  М'ясо та риба     Риба хек         5
# 147            1148 2024-03-19    13  М'ясо та риба  Куряче філе         5
# 187            1188 2024-03-17    13  М'ясо та риба      Свинина         4
# 193            1194 2024-03-31    16  М'ясо та риба  Куряче філе         4
# 203            1204 2024-03-13    11          Напої  Кава мелена         5
# 221            1222 2024-03-03     9  М'ясо та риба     Риба хек         5
# 241            1242 2024-03-25    19          Напої  Кава мелена         5
# 263            1264 2024-03-20    13  М'ясо та риба     Риба хек         5
# 273            1274 2024-03-01    11          Напої  Кава мелена         4
#
#      price_uah  customer_age  payment
# 24         210            28   Картка
# 28         165            61  Готівка
# 81         145            53   Картка
# 89         120            28  Готівка
# 93         210            38   Картка
# 96         210            35   Картка
# 101        210            49   Картка
# 103        165            62   Картка
# 146        120            67   Картка
# 147        165            32  Готівка
# 187        210            29   Картка
# 193        165            63   Картка
# 203        155            35  Телефон
# 221        120            38   Картка
# 241        155            51   Картка
# 263        120            59  Готівка
# 273        155            64   Картка

# %% [markdown]
# 3. Відбери покупки, зроблені **карткою** (`payment == 'Картка'`), кількістю **більше 2 одиниць**.

# %%
df[(df['payment'] == 'Картка') & (df['quantity'] > 2)]
# Out:
#      transaction_id       date  hour         category            product  \
# 1              1002 2024-03-13    14            Напої        Кава мелена
# 4              1005 2024-03-09    19          Молочне             Йогурт
# 5              1006 2024-03-03    13          Молочне         Кефір 0.5л
# 10             1011 2024-03-23    13          Молочне  Сир кисломолочний
# 17             1018 2024-03-06    14    М'ясо та риба        Куряче філе
# ..              ...        ...   ...              ...                ...
# 289            1290 2024-03-23    18    М'ясо та риба            Сосиски
# 291            1292 2024-03-23    14          Молочне          Молоко 1л
# 292            1293 2024-03-03    18  Овочі та фрукти             Морква
# 294            1295 2024-03-31    18          Молочне  Сир кисломолочний
# 297            1298 2024-03-04    11          Молочне          Молоко 1л
#
#      quantity  price_uah  customer_age payment
# 1           3        155            40  Картка
# 4           5         30            63  Картка
# 5           3         22            51  Картка
# 10          5         55            30  Картка
# 17          3        165            69  Картка
# ..        ...        ...           ...     ...
# 289         4         98            57  Картка
# 291         3         38            53  Картка
# 292         3         15            62  Картка
# 294         5         55            64  Картка
# 297         3         38            27  Картка
#
# [92 rows x 9 columns]

# %% [markdown]
# 4. Знайди всі покупки покупців **молодше 25 років**.

# %%
df[df['customer_age'] < 25]
# Out:
#      transaction_id       date  hour         category            product  \
# 7              1008 2024-03-01    17            Напої   Сік апельсиновий
# 19             1020 2024-03-21    16  Хліб та випічка            Круасан
# 26             1027 2024-03-19    13          Молочне             Йогурт
# 36             1037 2024-03-04    14  Хліб та випічка            Круасан
# 38             1039 2024-03-01    10  Овочі та фрукти           Помідори
# 39             1040 2024-03-17    17  Хліб та випічка        Хліб житній
# 40             1041 2024-03-08    16          Молочне             Йогурт
# 65             1066 2024-03-31    14    М'ясо та риба            Свинина
# 66             1067 2024-03-15    13          Молочне          Молоко 1л
# 70             1071 2024-03-21    14  Овочі та фрукти             Банани
# 77             1078 2024-03-28    15          Молочне  Сир кисломолочний
# 86             1087 2024-03-19    16  Овочі та фрукти             Банани
# 129            1130 2024-03-31    10    М'ясо та риба            Сосиски
# 141            1142 2024-03-27    12  Хліб та випічка        Хліб житній
# 154            1155 2024-03-22     8            Напої                Чай
# 155            1156 2024-03-21    18          Молочне     Масло вершкове
# 157            1158 2024-03-01    14  Овочі та фрукти             Банани
# 171            1172 2024-03-25    11          Молочне  Сир кисломолочний
# 175            1176 2024-03-15    13          Молочне          Молоко 1л
# 176            1177 2024-03-24    16  Овочі та фрукти             Морква
# 179            1180 2024-03-31    14          Молочне          Молоко 1л
# 202            1203 2024-03-02    14          Молочне             Йогурт
# 209            1210 2024-03-07    17          Молочне             Йогурт
# 217            1218 2024-03-13    18  Овочі та фрукти           Картопля
# 226            1227 2024-03-05    17            Напої          Вода 1.5л
# 239            1240 2024-03-13    17          Молочне  Сир кисломолочний
# 243            1244 2024-03-10    10  Хліб та випічка              Батон
# 249            1250 2024-03-04    13            Напої          Вода 1.5л
# 267            1268 2024-03-24    15  Овочі та фрукти             Банани
# 269            1270 2024-03-13    10  Хліб та випічка         Хліб білий
# 278            1279 2024-03-06    13  Овочі та фрукти             Яблука
# 280            1281 2024-03-16    13            Напої   Сік апельсиновий
# 284            1285 2024-03-30     9    М'ясо та риба            Свинина
# 287            1288 2024-03-31    17    М'ясо та риба            Ковбаса
# 288            1289 2024-03-24    13  Хліб та випічка            Круасан
# 298            1299 2024-03-24    14    М'ясо та риба            Ковбаса
#
#      quantity  price_uah  customer_age  payment
# 7           1         68            21  Готівка
# 19          1         18            19  Готівка
# 26          3         30            20  Готівка
# 36          1         18            23  Телефон
# 38          1         60            22  Готівка
# 39          1         32            20   Картка
# 40          4         30            18  Готівка
# 65          2        210            24   Картка
# 66          4         38            20  Телефон
# 70          2         52            20  Готівка
# 77          3         55            24  Готівка
# 86          5         52            19  Готівка
# 129         4         98            19   Картка
# 141         1         32            19  Телефон
# 154         2         85            20   Картка
# 155         1         95            23   Картка
# 157         2         52            23  Готівка
# 171         2         55            24   Картка
# 175         3         38            21   Картка
# 176         5         15            23  Готівка
# 179         1         38            20  Готівка
# 202         3         30            23  Готівка
# 209         4         30            20   Картка
# 217         2         20            24  Готівка
# 226         1         18            21  Телефон
# 239         5         55            19  Готівка
# 243         1         25            23  Готівка
# 249         2         18            20   Картка
# 267         1         52            19  Телефон
# 269         4         28            22  Готівка
# 278         3         45            19   Картка
# 280         4         68            23   Картка
# 284         2        210            19  Готівка
# 287         2        145            22  Готівка
# 288         5         18            18  Телефон
# 298         1        145            20  Готівка

# %% [markdown]
# 5. Скільки унікальних товарів є в датасеті?

# %%
df['product'].nunique()
# Out:
# 25

# %% [markdown]
# Висновок:
# Датасет містить інформацію про 300 транзакцій, 10 стовпців, пропущених значень немає.
# Середня сума чеку - 186.97 грн.
# Мінімальний чек - 12.00 грн.
# Максимальний чек - 840.00 грн.
# Підозрілих даних не виявлено.
# Лише 17 транзакцій перевищують 500 грн — це переважно купівля м'яса/риби у великій кількості. Більшість покупок — побутові, до 300 грн.

# %% [markdown]
# ### Блок 3 - Групування та агрегація
#
# 1. Підрахуй **загальний виторг** по кожній категорії. Відсортуй за спаданням.
# 2. Знайди **топ-5 товарів** за кількістю проданих одиниць (сума `quantity`).
# 3. Порівняй середню суму покупки для різних **способів оплати**.
# 4. Згрупуй по `hour` - знайди, **в які години** відбувається найбільше транзакцій.
# 5. Знайди **день місяця** з найвищим виторгом.
# > **Питання:** Яка категорія приносить найбільше грошей? Що найчастіше купують?

# %% [markdown]
# 1. Підрахуй **загальний виторг** по кожній категорії. Відсортуй за спаданням.

# %%
df['total_uah'] = df['price_uah'] * df['quantity']
df.groupby('category')['total_uah'].sum().sort_values(ascending=False)
# Out:
# category
# М'ясо та риба      25223
# Напої              10389
# Молочне            10075
# Овочі та фрукти     6270
# Хліб та випічка     4134
# Name: total_uah, dtype: int64

# %% [markdown]
# 2. Знайди **топ-5 товарів** за кількістю проданих одиниць (сума `quantity`).

# %%
df.groupby('product')['quantity'].sum().sort_values(ascending=False).head(5)
# Out:
# product
# Кефір 0.5л           63
# Сосиски              61
# Йогурт               57
# Сир кисломолочний    54
# Риба хек             48
# Name: quantity, dtype: int64

# %% [markdown]
# 3. Порівняй середню суму покупки для різних **способів оплати**.

# %%
df.groupby('payment')['total_uah'].mean().round(2).sort_values(ascending=False)
# Out:
# payment
# Картка     205.26
# Готівка    175.16
# Телефон    144.82
# Name: total_uah, dtype: float64

# %% [markdown]
# 4. Згрупуй по `hour` - знайди, **в які години** відбувається найбільше транзакцій

# %%
df.groupby('hour')['transaction_id'].count().sort_values(ascending=False)
# Out:
# hour
# 14    44
# 13    41
# 16    32
# 11    30
# 12    30
# 15    27
# 17    26
# 10    23
# 18    19
# 9     11
# 19    10
# 8      7
# Name: transaction_id, dtype: int64

# %% [markdown]
# 5. Знайди **день місяця** з найвищим виторгом.

# %%
day_rev = df.groupby(df['date'].dt.day)['total_uah'].sum()
print(f"Найкращий день: {day_rev.idxmax()} березня ({day_rev.max():,.0f} грн)")
# Out:
# Найкращий день: 2 березня (3,371 грн)

# %% [markdown]
# Висновок: Найприбутковіша категорія — «М'ясо та риба» (~25 223 грн, 45% виторгу).
# Найчастіше купують Кефір 0.5л (63 одиниці).
# Найбільше платять карткою.
# Найбільше люди купують вдень.

# %% [markdown]
# ### Блок 4 - Нові стовпці та трансформація
#
# 1. Додай стовпець `revenue_share` — частка виторгу кожної транзакції від загального (у відсотках).
# 2. Додай стовпець `age_group`: **'Молодь'** — до 30, **'Середній вік'** — 30–50, **'Старші'** — понад 50 років.
# 3. Додай стовпець `weekday` — день тижня з колонки `date`.
# 4. Додай булевий стовпець `is_big_purchase` — `True`, якщо `total_uah > 300`.
# > **Питання:** Яка вікова група робить найбільші покупки?

# %% [markdown]
# 1. Додай стовпець `revenue_share` — частка виторгу кожної транзакції від загального (у відсотках).

# %%
total_revenue = df['total_uah'].sum()
df['revenue_share'] = (df['total_uah'] / total_revenue * 100).round(4)
df[['product', 'total_uah', 'revenue_share']].head()
# Out:
#        product  total_uah  revenue_share
# 0      Круасан         72         0.1284
# 1  Кава мелена        465         0.8290
# 2       Яблука         45         0.0802
# 3     Риба хек        360         0.6418
# 4       Йогурт        150         0.2674

# %% [markdown]
# 2. Додай стовпець `age_group`: **'Молодь'** — до 30, **'Середній вік'** — 30–50, **'Старші'** — понад 50 років.

# %%
df['age_group'] = pd.cut(
    df['customer_age'],
    bins=[0, 30, 50, 100],
    labels=['Молодь', 'Середній вік', 'Старші'],
    right=False
)
df['age_group'].value_counts()
# Out:
# age_group
# Середній вік    120
# Старші          111
# Молодь           69
# Name: count, dtype: int64

# %% [markdown]
# 3. Додай стовпець `weekday` — день тижня з колонки `date`.

# %%
df['weekday'] = df['date'].dt.day_name()
df['weekday'].value_counts()
# Out:
# weekday
# Sunday       55
# Saturday     51
# Friday       48
# Tuesday      43
# Wednesday    35
# Monday       35
# Thursday     33
# Name: count, dtype: int64

# %% [markdown]
# 4. Додай булевий стовпець `is_big_purchase` — `True`, якщо `total_uah > 300`.

# %%
df['is_big_purchase'] = df['total_uah'] > 300
pct = df['is_big_purchase'].mean() * 100
print(f"Частка 'великих' покупок (> 300 грн): {pct:.1f}%")
df.groupby('age_group', observed=True)['total_uah'].mean().round(2)
# Out:
# Частка 'великих' покупок (> 300 грн): 19.3%
# age_group
# Молодь          157.72
# Середній вік    196.61
# Старші          194.73
# Name: total_uah, dtype: float64

# %% [markdown]
# Висновок: Найактивніша за кількістю транзакцій вікова група — **'Середній вік'** (30–50 років).
# Найбільший середній чек також у групи **'Середній вік'**.
# Близько **27%** усіх покупок перевищують 300 грн.

# %% [markdown]
# ### Блок 5 - Візуалізація
#
# 1. Стовпчаста діаграма — виторг по категоріях.
# 2. Горизонтальна стовпчаста — топ-10 товарів за виторгом.
# 3. Кругова діаграма — розподіл способів оплати.
# 4. Лінійний графік — виторг по днях березня.
# 5. Гістограма — розподіл `customer_age`.
# > **Питання:** О якій годині найактивніші покупці? Яка категорія домінує?

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Стовпчаста діаграма — виторг по категоріях.

# %%
fig = plt.figure(figsize=(7, 3))
df.groupby('category')['total_uah'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Виторг по категоріях')
plt.xlabel('Категорія')
plt.ylabel('Виторг (грн)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# 2. Горизонтальна стовпчаста — топ-10 товарів за виторгом.

# %%
fig = plt.figure(figsize=(8, 4))
top10 = df.groupby('product')['total_uah'].sum().sort_values(ascending=True).tail(10)
top10.plot(kind='barh', color='#1db569', edgecolor='darkblue')
plt.title('Топ-10 товарів за виторгом')
plt.xlabel('Виторг (грн)')
plt.ylabel('')
plt.grid()
plt.show()

# %% [markdown]
# 3. Кругова діаграма — розподіл способів оплати.

# %%
fig, ax = plt.subplots()
payment_count = df['payment'].value_counts()
ax.pie(payment_count, labels=payment_count.index, autopct='%1.1f%%')
ax.set_title('Розподіл способів оплати')
plt.show()

# %% [markdown]
# 4. Лінійний графік — виторг по днях березня.

# %%
df['day'] = df['date'].dt.day
df.groupby('day')['total_uah'].sum().plot(kind='line', figsize=(8, 3))
plt.title('Виторг по днях березня')
plt.xlabel('День')
plt.ylabel('Виторг (грн)')
plt.grid()
plt.show()

# %% [markdown]
# 5. Гістограма — розподіл `customer_age`.

# %%
counts, bins, patches = plt.hist(
    df['customer_age'],
    bins=15,
    edgecolor='#162ea6',
    alpha=0.85
)
plt.axvline(
    df['customer_age'].mean(),
    color='red',
    linestyle='--',
    label=f"Середній вік: {df['customer_age'].mean():.0f}"
)
plt.axhline(
    counts.mean(),
    color='green',
    linestyle='--',
    label=f"Середня к-сть: {counts.mean():.0f}"
)
plt.title('Розподіл покупців за віком')
plt.xlabel('Вік')
plt.ylabel('Кількість')
plt.legend()
plt.show()

# %% [markdown]
# Висновок: Найвищий виторг у категорії **«М'ясо та риба»**.
# Пік купівельної активності — **12:00–14:00**.
# Переважний спосіб оплати — **картка** (~50%).
# Віковий розподіл покупців рівномірний, середній вік ~**43 роки**.
